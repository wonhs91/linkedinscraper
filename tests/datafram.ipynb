# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect('data/my_database - Copy.db')

df = pd.read_sql_query("SELECT * FROM jobs WHERE DATE(date_loaded) = DATE('now', 'localtime)", conn)

# %%
df
# Out:
#    id                                          title  \
# 0   1                               Gen AI Architect
# 1   2             Gen AI Architect / AI/ML Architect
# 2   3                      Head of Product Marketing
# 3   4             Lead Gen Video and Copy Specialist
# 4   5                         ML Engineer II- Gen AI
# 5   6           Operations Leadership, Generative AI
# 6   7       Senior Growth Marketing Creative Manager
# 7   8  Senior Software Engineer, GenAI Model Quality
# 8   9         Software Engineer, GenAI Model Quality
# 9  10         entry level java developer with string
#
#                     company                 location        date  \
# 0  First Soft Solutions LLC            United States  2024-12-10
# 1             GAC Solutions            United States  2024-12-10
# 2                   OVERJET            Palo Alto, CA  2024-12-10
# 3                   Grow.fm         Santa Monica, CA  2024-12-10
# 4        Guidewire Software            San Mateo, CA  2024-12-10
# 5                  Scale AI        San Francisco, CA  2024-12-10
# 6                    Roblox            San Mateo, CA  2024-12-10
# 7                  Scale AI  New York, United States  2024-12-10
# 8                  Scale AI  New York, United States  2024-12-10
# 9             SynergisticIT            Arlington, VA  2024-12-10
#
#                                           job_url  \
# 0  https://www.linkedin.com/jobs/view/4095887541/
# 1  https://www.linkedin.com/jobs/view/4096127122/
# 2  https://www.linkedin.com/jobs/view/4004842449/
# 3  https://www.linkedin.com/jobs/view/4096156912/
# 4  https://www.linkedin.com/jobs/view/4096908463/
# 5  https://www.linkedin.com/jobs/view/3995287184/
# 6  https://www.linkedin.com/jobs/view/4077292707/
# 7  https://www.linkedin.com/jobs/view/4017906017/
# 8  https://www.linkedin.com/jobs/view/3995281827/
# 9  https://www.linkedin.com/jobs/view/4096173010/
#
#                                      job_description remote_status  \
# 0  Job Title - GenAI Architect \n-  10+ years of ...          None
# 1  Gen AI Architect        \n            \n      ...          None
# 2  Lead the Future of Dentistry. \nOverjet is the...          None
# 3  Lead Gen Video and Copy Specialist\n- - - - - ...          None
# 4  Summary\nYour day-to-day:\nBe part of a cross-...          None
# 5  Scale’s Generative AI business unit is less th...          None
# 6  Every day, tens of millions of people come to ...          None
# 7  About Scale\nAt Scale AI, our mission is to ac...          None
# 8  About Scale\nAt Scale AI, our mission is to ac...          None
# 9  https://www.synergisticit.com/candidate-outcom...          None
#
#           recruiter_name                                 recruiter_position  \
# 0                   None                                               None
# 1  Nanda Kishore Nimmoju  Global Talent Acquisition | Expert in Strategi...
# 2                   None                                               None
# 3            Chris Marin  CEO Convert.ai | Pay Per B2B Meetings at Scale...
# 4                   None                                               None
# 5                   None                                               None
# 6                   None                                               None
# 7                   None                                               None
# 8                   None                                               None
# 9                   None                                               None
#
#                   date_loaded  \
# 0  2024-12-10 23:42:44.888966
# 1  2024-12-10 23:42:44.888966
# 2  2024-12-10 23:42:44.888966
# 3  2024-12-10 23:42:44.888966
# 4  2024-12-10 23:42:44.888966
# 5  2024-12-10 23:42:44.888966
# 6  2024-12-10 23:42:44.888966
# 7  2024-12-10 23:42:44.888966
# 8  2024-12-10 23:42:44.888966
# 9  2024-12-10 23:42:44.888966
#
#                                              address       phone_number  \
# 0                                               None               None
# 1  No 16, 2nd Floor, 80 Feet Road, 4th Block, Kor...   +91 80 2553 2414
# 2                                 Seoul, South Korea    +82-2-1234-5678
# 3  Grow.fm, 251 Little Falls Dr, Wilmington, DE 1...     (555) 123-4567
# 4  1001 E Hillsdale Blvd, Foster City, CA 94404, USA    +1 650-357-9100
# 5                                  San Francisco, CA     (415) 964-3774
# 6                                               None               None
# 7                                  San Francisco, CA  +1 (415) 964-3774
# 8                                  San Francisco, CA  +1 (415) 964-3774
# 9                                               None               None
#
#                                        main_products match_percentage  \
# 0                                               None               85
# 1  [{'name': 'Digital Transformation Solutions', ...             None
# 2  [{'name': 'OVERJET Dental 3D Printer', 'descri...               20
# 3  [{'name': 'Grow', 'description': 'An AI-powere...               10
# 4  [{'name': 'Guidewire PolicyCenter', 'descripti...               82
# 5  [{'name': 'Scale AI Acceleration Platform', 'd...               75
# 6                                               None               10
# 7  [{'name': 'Scale AI Acceleration Platform', 'd...             None
# 8  [{'name': 'Scale AI API', 'description': 'A cl...               85
# 9                                               None               85
#
#                                   overall_assessment  \
# 0  The candidate has a strong background in AI, M...
# 1                                               None
# 2  The candidate's skills and preferences do not ...
# 3  The candidate's skills do not align with the j...
# 4  The candidate's skills and preferences align w...
# 5  The candidate's technical skills and entrepren...
# 6  The candidate's skills and preferences do not ...
# 7                                               None
# 8  The candidate's skills and preferences align w...
# 9  The candidate's skills and preferences demonst...
#
#                               recommended_next_steps  \
# 0  ['Highlight transferable skills', 'Address lea...
# 1                                               None
# 2  ['Explore related roles that combine technical...
# 3  ['Consider technical roles aligning with curre...
# 4  ['Acquire experience with statistical learning...
# 5  ['Provide detailed experience information.', '...
# 6  ['The candidate should consider roles that ali...
# 7                                               None
# 8  ['Learn more about the Generative AI Data Engi...
# 9  ['Highlight transferable skills', 'Develop ind...
#
#                                       matched_skills  \
# 0  [{'skill': 'Python', 'criticality': 'High'}, {...
# 1                                               None
# 2                                                 []
# 3                                                 []
# 4  [{'skill': 'Python Programming Language', 'cri...
# 5  [{'skill': 'Technical Background', 'criticalit...
# 6                                                 []
# 7                                               None
# 8  [{'skill': 'Programming Languages', 'criticali...
# 9  [{'skill': 'Python', 'criticality': 'High'}, {...
#
#                                           skill_gaps
# 0  [{'skill': 'Leadership Experience', 'criticali...
# 1                                               None
# 2  [{'skill': 'Product Marketing experience', 'cr...
# 3  [{'skill': 'Content Creation', 'criticality': ...
# 4  [{'skill': 'Statistical Learning Algorithms', ...
# 5  [{'skill': 'Specific Experience', 'criticality...
# 6  [{'skill': 'Growth marketing expertise', 'crit...
# 7                                               None
# 8  [{'skill': 'Generative AI Data Engine', 'criti...
# 9  [{'skill': 'Industry-specific knowledge', 'cri...

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")

cursor.fetchall()
# Out:
# [('jobs',), ('sqlite_sequence',), ('filtered_jobs',)]
